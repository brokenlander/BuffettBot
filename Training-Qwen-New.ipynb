# %%
from unsloth import FastLanguageModel
import torch
import json
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
models = [
    "unsloth/Mistral-Small-3.1-24B-Base-2503",
    "unsloth/Qwen3-32B",
    "unsloth/gemma-3-27b-it"
    "unsloth/Llama-3.3-70B-Instruct"
] 

dtype = None
load_in_4bit = False
max_seq_length = 8192

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = models[1],
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# ==((====))==  Unsloth 2025.11.2: Fast Qwen3 patching. Transformers: 4.57.1.
#    \\   /|    NVIDIA H100 PCIe. Num GPUs = 1. Max memory: 79.189 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu128. CUDA: 9.0. CUDA Toolkit: 12.8. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# model-00001-of-00014.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00002-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00003-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00004-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00005-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00006-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00007-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00008-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00009-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00010-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00011-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00012-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00013-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00014-of-00014.safetensors:   0%|          | 0.00/2.08G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/14 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 32, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 32,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.11.2 patched 64 layers with 64 QKV layers, 64 O layers and 64 MLP layers.

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "qwen-2.5",
)

def formatting_prompts_func(examples):
    convos = examples["conversations"]
    texts = [
        tokenizer.apply_chat_template(
            convo, 
            tokenize=False, 
            add_generation_prompt=False
        )
        for convo in convos
    ]
    return {"text": texts}

# %%
from datasets import load_dataset
dataset = load_dataset(
    "json",
    data_files = "/home/ubuntu/AlphaBuffett/Dataset/Processed/Ground Truth/dataset_combined.json",
    split = "train",
)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset[5]['conversations']
# Out:
# [{'from': 'human',
#   'value': 'How do you approach the challenge of maintaining discipline when market conditions soften and competitors start offering unrealistic rates?'},
#  {'from': 'gpt',
#   'value': "This is one of the most difficult challenges in our insurance operations, and it requires what I call unusual managerial discipline. You see, when markets loosen and rates become inadequate, the natural institutional behavior is to fight to keep your business. Nobody likes to see the other fellow take away their customers. But we've learned that you sometimes have to philosophically accept reduced volume. Look at what happened with National Indemnity - we've had excellent underwriting margins and large volume gains when many competitors contracted or withdrew after the 1974-75 crisis. But these conditions won't last forever. When the market softens, we have to be willing to let business go when prices become foolish. It's like being the designated driver at a party - you might not be having as much fun as everyone else, but you're making the right long-term decision. The key is maintaining that discipline even when it runs counter to what everyone else is doing. It's not easy, but it's essential for long-term success in the insurance business."}]

# %%
from unsloth.chat_templates import standardize_sharegpt

dataset = standardize_sharegpt(dataset)
# Out:
# Unsloth: Standardizing formats (num_proc=26):   0%|          | 0/7265 [00:00<?, ? examples/s]

# %%
dataset[5]['conversations']
# Out:
# [{'content': 'How do you approach the challenge of maintaining discipline when market conditions soften and competitors start offering unrealistic rates?',
#   'role': 'user'},
#  {'content': "This is one of the most difficult challenges in our insurance operations, and it requires what I call unusual managerial discipline. You see, when markets loosen and rates become inadequate, the natural institutional behavior is to fight to keep your business. Nobody likes to see the other fellow take away their customers. But we've learned that you sometimes have to philosophically accept reduced volume. Look at what happened with National Indemnity - we've had excellent underwriting margins and large volume gains when many competitors contracted or withdrew after the 1974-75 crisis. But these conditions won't last forever. When the market softens, we have to be willing to let business go when prices become foolish. It's like being the designated driver at a party - you might not be having as much fun as everyone else, but you're making the right long-term decision. The key is maintaining that discipline even when it runs counter to what everyone else is doing. It's not easy, but it's essential for long-term success in the insurance business.",
#   'role': 'assistant'}]

# %%
dataset = dataset.map(formatting_prompts_func, batched=True)
# Out:
# Map:   0%|          | 0/7265 [00:00<?, ? examples/s]

# %%
dataset[5]
# Out:
# {'conversations': [{'content': 'How do you approach the challenge of maintaining discipline when market conditions soften and competitors start offering unrealistic rates?',
#    'role': 'user'},
#   {'content': "This is one of the most difficult challenges in our insurance operations, and it requires what I call unusual managerial discipline. You see, when markets loosen and rates become inadequate, the natural institutional behavior is to fight to keep your business. Nobody likes to see the other fellow take away their customers. But we've learned that you sometimes have to philosophically accept reduced volume. Look at what happened with National Indemnity - we've had excellent underwriting margins and large volume gains when many competitors contracted or withdrew after the 1974-75 crisis. But these conditions won't last forever. When the market softens, we have to be willing to let business go when prices become foolish. It's like being the designated driver at a party - you might not be having as much fun as everyone else, but you're making the right long-term decision. The key is maintaining that discipline even when it runs counter to what everyone else is doing. It's not easy, but it's essential for long-term success in the insurance business.",
#    'role': 'assistant'}],
#  'text': "<|im_start|>system\nYou are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>\n<|im_start|>user\nHow do you approach the challenge of maintaining discipline when market conditions soften and competitors start offering unrealistic rates?<|im_end|>\n<|im_start|>assistant\nThis is one of the most difficult challenges in our insurance operations, and it requires what I call unusual managerial discipline. You see, when markets loosen and rates become inadequate, the natural institutional behavior is to fight to keep your business. Nobody likes to see the other fellow take away their customers. But we've learned that you sometimes have to philosophically accept reduced volume. Look at what happened with National Indemnity - we've had excellent underwriting margins and large volume gains when many competitors contracted or withdrew after the 1974-75 crisis. But these conditions won't last forever. When the market softens, we have to be willing to let business go when prices become foolish. It's like being the designated driver at a party - you might not be having as much fun as everyone else, but you're making the right long-term decision. The key is maintaining that discipline even when it runs counter to what everyone else is doing. It's not easy, but it's essential for long-term success in the insurance business.<|im_end|>\n"}

# %%
#EARLY STOPPING / TEST SIZE / EPOCHS / LEARNING RATE

from trl import SFTTrainer
from transformers import TrainingArguments, DataCollatorForSeq2Seq, EarlyStoppingCallback
from unsloth import is_bfloat16_supported

# Fix: Handle if dataset is already a DatasetDict
if hasattr(dataset, 'keys'):  # It's a DatasetDict
    dataset = dataset["train"]  # Get the train split

# Now split it
dataset_split = dataset.train_test_split(test_size=0.15, seed=42)

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset_split["train"],  # 85% for training
    eval_dataset = dataset_split["test"],    # 15% for validation
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    data_collator = DataCollatorForSeq2Seq(tokenizer = tokenizer),
    dataset_num_proc = 2,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_ratio = 0.05,
        num_train_epochs = 2,
        learning_rate = 1e-4,
        eval_strategy = "steps",
        eval_steps = 50,
        save_strategy = "steps",
        save_steps = 50,
        save_total_limit = 3,
        load_best_model_at_end = True,
        metric_for_best_model = "eval_loss",
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 10,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "cosine",
        seed = 3407,
        output_dir = "outputs/qwen-buffett-1epoch",
        report_to = "none",
    ),
    callbacks = [EarlyStoppingCallback(early_stopping_patience=3)],
)

# %%
from trl import SFTTrainer
from transformers import TrainingArguments, DataCollatorForSeq2Seq
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    data_collator = DataCollatorForSeq2Seq(tokenizer = tokenizer),
    dataset_num_proc = 2,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        num_train_epochs = 2,
        learning_rate = 1e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none",
    ),
)

# %%
from unsloth.chat_templates import train_on_responses_only
trainer = train_on_responses_only(
    trainer,
    instruction_part="<|im_start|>user",
    response_part="<|im_start|>assistant",
)
# Out:
# Map (num_proc=30):   0%|          | 0/7265 [00:00<?, ? examples/s]

# %%
tokenizer.decode(trainer.train_dataset[5]["input_ids"])
# Out:
# "<|im_start|>system\nYou are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>\n<|im_start|>user\nHow do you approach the challenge of maintaining discipline when market conditions soften and competitors start offering unrealistic rates?<|im_end|>\n<|im_start|>assistant\nThis is one of the most difficult challenges in our insurance operations, and it requires what I call unusual managerial discipline. You see, when markets loosen and rates become inadequate, the natural institutional behavior is to fight to keep your business. Nobody likes to see the other fellow take away their customers. But we've learned that you sometimes have to philosophically accept reduced volume. Look at what happened with National Indemnity - we've had excellent underwriting margins and large volume gains when many competitors contracted or withdrew after the 1974-75 crisis. But these conditions won't last forever. When the market softens, we have to be willing to let business go when prices become foolish. It's like being the designated driver at a party - you might not be having as much fun as everyone else, but you're making the right long-term decision. The key is maintaining that discipline even when it runs counter to what everyone else is doing. It's not easy, but it's essential for long-term success in the insurance business.<|im_end|>\n"

# %%
# Get a sample from the trainer's dataset
sample = trainer.train_dataset[5]
labels = sample["labels"]

# Now check what's being trained on
space = tokenizer(text=" ", add_special_tokens=False).input_ids[0]
filtered = [space if x == -100 else x for x in labels]
tokenizer.decode(filtered)
# Out:
# "                                                \nThis is one of the most difficult challenges in our insurance operations, and it requires what I call unusual managerial discipline. You see, when markets loosen and rates become inadequate, the natural institutional behavior is to fight to keep your business. Nobody likes to see the other fellow take away their customers. But we've learned that you sometimes have to philosophically accept reduced volume. Look at what happened with National Indemnity - we've had excellent underwriting margins and large volume gains when many competitors contracted or withdrew after the 1974-75 crisis. But these conditions won't last forever. When the market softens, we have to be willing to let business go when prices become foolish. It's like being the designated driver at a party - you might not be having as much fun as everyone else, but you're making the right long-term decision. The key is maintaining that discipline even when it runs counter to what everyone else is doing. It's not easy, but it's essential for long-term success in the insurance business.<|im_end|>\n"

# %%
# Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA H100 PCIe. Max memory = 79.189 GB.
# 62.096 GB of memory reserved.

# %%
import os
os.environ['UNSLOTH_RETURN_LOGITS'] = '1'
trainer_stats = trainer.train()
# Out:
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 7,265 | Num Epochs = 2 | Total steps = 1,818
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 268,435,456 of 33,030,558,720 (0.81% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='1818' max='1818' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1818/1818 1:19:15, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.393000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.447300</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.357800</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.329900</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.379000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.214000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.253900</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.156600</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.234700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.946500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.029300</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.986900</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.873100</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.222500</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.071300</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.028500</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.934700</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.929900</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.957300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.877700</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.912300</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.919200</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.633300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.822300</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.843600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.963500</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.818200</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.758900</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.825800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.846800</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.799200</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.874500</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.825300</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.994600</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.847200</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.766400</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.879900</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.757300</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.941700</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.740700</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.682300</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.552200</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.740400</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.942300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.773000</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.731700</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.751100</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.826200</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.703500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.802800</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.727600</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.752500</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.731500</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.684400</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.811900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.787200</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.697700</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.734500</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.771200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.717800</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.689300</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.859600</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1.819000</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.819400</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.740400</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.719800</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1.653900</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.812400</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1.685000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.762000</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>1.640300</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.721300</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.814700</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.907000</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.722400</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.864800</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>1.782900</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.699600</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.950800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.869600</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.775800</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.647000</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.801500</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>1.755000</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.689900</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.592000</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.803800</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.764400</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.945200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.782500</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>1.704600</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.713800</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.669500</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.780700</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.753800</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>1.698100</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.707600</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.724900</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>1.812600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.631800</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>1.794700</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>1.676300</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>1.646000</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>1.744000</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>1.734900</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>1.730000</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>1.723200</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>1.705100</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>1.741800</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.706300</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>1.787100</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>1.823200</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.673100</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>1.890400</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>1.686000</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>1.815700</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>1.895600</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.789300</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>1.788800</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.756100</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>1.901400</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>1.703800</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>1.667400</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>1.812600</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.698400</td>
#     </tr>
#     <tr>
#       <td>

# %%
# Set model to inference mode
FastLanguageModel.for_inference(model)
from transformers import TextStreamer

# Enable streaming
text_streamer = TextStreamer(tokenizer, skip_prompt=True)

# Test questions
test_questions = [
    "What is your investment philosophy?",
    "How do you evaluate a company?",
    "What makes a good business?"
]

for question in test_questions:
    print(f"\n{'='*50}")
    print(f"Q: {question}")
    print(f"{'='*50}")
    print("A: ", end="")
    
    # Use the tokenizer's apply_chat_template
    messages = [{"role": "user", "content": question}]
    
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )
    
    # Tokenize
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        add_special_tokens=False
    ).to("cuda")
    
    # Generate
    outputs = model.generate(
        **inputs,
        streamer=text_streamer,
        max_new_tokens=1024,
        temperature=0.75,
        top_p=0.92,
        repetition_penalty=1.1,
        do_sample=True,
        pad_token_id=tokenizer.pad_token_id,
        eos_token_id=tokenizer.eos_token_id
    )
    print("\n")
# Out:
# ==================================================
# Q: What is your investment philosophy?
# ==================================================
# A: Our investment approach is really quite straightforward - we look for good businesses at fair prices and focus on the long-term prospects rather than trying to time the market or make short-term predictions about stock price movements. We're interested in finding excellent companies with strong fundamentals that we can understand. When we find those characteristics, we try to buy them at reasonable prices relative to their intrinsic value. This might sound simple, but it's worked pretty well for us over many decades. The key difference between our approach and what you see from most Wall Street analysts and brokers is that we don't play games with timing the market or making short-term forecasts about stock price movements. Instead, we concentrate on understanding the underlying business quality and valuation. It's like having a great garden - if you plant good seeds (good businesses) in good soil (at fair prices), and take care of them properly, you'll eventually get a bountiful harvest regardless of whether you water them every day or only occasionally.<|im_end|>
#
#
#
# ==================================================
# Q: How do you evaluate a company?
# ==================================================
# A: Let me be clear about this - we don't start by looking at the balance sheet or income statement first. We approach it like how I'd evaluate my farming operation in Nebraska. First, I'd want to know what crops we're going to plant and when they'll come in - that's understanding the business model. Then I'd look for competitive advantages, like having a unique water source that gives us an edge over neighboring farms. And finally, I'd examine who we're competing against and whether our advantage is sustainable. That's exactly how we evaluate businesses too. We focus on understanding the fundamental characteristics of the business - its economic moat, competitive position, and long-term prospects before diving into financial statements. It's about seeing the whole picture, not just the numbers. When you understand these core aspects, the financial analysis becomes much more meaningful.<|im_end|>
#
#
#
# ==================================================
# Q: What makes a good business?
# ==================================================
# A: The answer is really quite simple - you want to be in businesses that earn high returns on capital and require low incremental capital investment as sales grow. Let me explain why this matters so much. When we look at businesses like Coca-Cola or Gillette, they're perfect examples of what we seek. These companies have built incredibly strong franchises over decades. They've managed to achieve two critical things: first, they generate excellent returns on the money they put into their operations, and secondly, they don't need to keep pouring more and more cash into the business just to grow sales. This is particularly important because most businesses work differently - they typically need substantial additional capital investment for every dollar increase in sales. But these exceptional businesses can grow substantially while requiring minimal new capital. That's what creates real value over time. It's not about having the flashiest technology or being in the hottest sector - it's about finding businesses with sustainable competitive advantages that let them compound value efficiently over long periods.<|im_end|>

# %%
# Set model to inference mode
FastLanguageModel.for_inference(model)
from transformers import TextStreamer

# Enable streaming
text_streamer = TextStreamer(tokenizer, skip_prompt=True)

# Simulate a multi-turn conversation where follow-up relies on previous context
conversation = [
    {"role": "user", "content": "What is your investment philosophy?"},
    {"role": "assistant", "content": "Our approach is really quite simple - we're looking for large businesses with understandable, enduring and what I like to call 'mouth-watering' economics. But it's not just about the business itself. We want these companies to be run by able and shareholder-oriented managements. And here's something crucial - we need a sensible price tag attached. We stick to what we understand and what has worked for us over time."},
    {"role": "user", "content": "Can you give me a specific example of a company that demonstrates this philosophy?"},
    {"role": "assistant", "content": "Look at See's Candy. When we bought it in 1972 for $25 million, it had exactly those characteristics I just mentioned - understandable business, mouth-watering economics, and great management. The brand had real pricing power, and customers loved it. Since then, we've put $40 million into it and it's given us over $1 billion pretax."},
    {"role": "user", "content": "You mentioned See's has given you over $1 billion pretax on a $25 million investment. What specifically about their pricing power made those economics so attractive? And how much of that $40 million you put in was actually needed versus optional expansion?"}
]

print("="*60)
print("MULTI-TURN CONVERSATION TEST")
print("="*60)
print("\n[Previous conversation about investment philosophy and See's Candy...]")
print(f"\nUser: {conversation[-1]['content']}")
print("Warren: ", end="")

prompt = tokenizer.apply_chat_template(
    conversation,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(prompt, return_tensors="pt", add_special_tokens=False).to("cuda")

outputs = model.generate(
    **inputs,
    streamer=text_streamer,
    max_new_tokens=512,
    temperature=0.75,
    top_p=0.92,
    repetition_penalty=1.1,
    do_sample=True,
    pad_token_id=tokenizer.pad_token_id,
    eos_token_id=tokenizer.eos_token_id
)
print("\n")
# Out:
# ============================================================
# MULTI-TURN CONVERSATION TEST
# ============================================================
#
# [Previous conversation about investment philosophy and See's Candy...]
#
# User: You mentioned See's has given you over $1 billion pretax on a $25 million investment. What specifically about their pricing power made those economics so attractive? And how much of that $40 million you put in was actually needed versus optional expansion?
# Warren: Well, let me tell you about that fascinating story. See's was already doing $38 million in sales when we bought them. That's pretty remarkable considering they were only open four months out of the year back then! Here's the key thing: while competitors tried to compete on price, See's had the luxury of competing on quality instead. They could sell at premium prices because people genuinely wanted their products. Now regarding our investments - of that $40 million we've put in since, maybe around $6-7 million was necessary to fund working capital needs due to their seasonal nature. But most of it went toward opening new stores, which was purely an option. We weren't forced to do any of it - but we did it anyway because we saw clear opportunities for growth within our circle of competence.<|im_end|>

# %%
hf_key = "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"
repo = "BuffettBot-Qwenv2"

# %%
from huggingface_hub import delete_repo, create_repo

delete_repo(
    repo_id=repo,
    token=hf_key,
    missing_ok = True
)

# Create the repo
create_repo(
    repo_id=repo,
    token=hf_key,
    private=True,
    repo_type="model"
)
# Out:
# RepoUrl('https://huggingface.co/brokenlander/BuffettBot-Qwenv2', endpoint='https://huggingface.co', repo_type='model', repo_id='brokenlander/BuffettBot-Qwenv2')

# %%
# save_method = "merged_4bit" or "merged_16bit"

model.push_to_hub_merged("brokenlander/"+repo, tokenizer, save_method = "merged_16bit", commit_message = "Initial Commit", commit_description = "Initial Commit after Lora Fine Tuning", token = hf_key, private = True)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Found HuggingFace hub cache directory: /home/ubuntu/.cache/huggingface/hub
# Checking cache directory for required files...
# Unsloth: Copying 14 files from cache to `brokenlander/BuffettBot-Qwenv2`: 100%|██████████| 14/14 [00:38<00:00,  2.78s/it]
# Successfully copied all 14 files from cache to `brokenlander/BuffettBot-Qwenv2`
# Checking cache directory for required files...
# Cache check failed: tokenizer.model not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Unsloth: Preparing safetensor model files: 100%|██████████| 14/14 [00:00<00:00, 107941.65it/s]
# Unsloth: Merging weights into 16bit:   0%|          | 0/14 [00:00<?, ?it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Unsloth: Merging weights into 16bit:   0%|          | 0/14 [00:58<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 3
#       1 # save_method = "merged_4bit" or "merged_16bit"
# ----> 3 model.push_to_hub_merged("brokenlander/"+repo, tokenizer, save_method = "merged_16bit", commit_message = "Initial Commit", commit_description = "Initial Commit after Lora Fine Tuning", token = hf_key, private = True)
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/unsloth/save.py:2732, in unsloth_generic_push_to_hub_merged(self, repo_id, tokenizer, save_method, use_temp_dir, commit_message, private, token, max_shard_size, create_pr, safe_serialization, revision, commit_description, tags, temporary_location, maximum_memory_usage)
#    2730 del arguments["self"]
#    2731 del arguments["repo_id"]
# -> 2732 unsloth_generic_save(**arguments)
#    2733 for _ in range(3):
#    2734     gc.collect()
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/unsloth/save.py:2636, in unsloth_generic_save(model, tokenizer, save_directory, save_method, push_to_hub, token, is_main_process, state_dict, save_function, max_shard_size, safe_serialization, variant, save_peft_format, use_temp_dir, commit_message, private, create_pr, revision, commit_description, tags, temporary_location, maximum_memory_usage)
#    2633 elif save_method == "merged_4bit_forced":
#    2634     save_method = "merged_4bit"
# -> 2636 merge_and_overwrite_lora(
#    2637     get_model_name,
#    2638     model = model,
#    2639     tokenizer = tokenizer,
#    2640     save_directory = save_directory,
#    2641     push_to_hub = push_to_hub,
#    2642     private = private,
#    2643     token = token,
#    2644     save_method = save_method,
#    2645     output_dtype = None,
#    2646     low_disk_space_usage = True,
#    2647     use_temp_file = False,
#    2648 )
#    2649 return
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/unsloth_zoo/saving_utils.py:1339, in merge_and_overwrite_lora(get_model_name, model, tokenizer, save_directory, push_to_hub, private, token, save_method, output_dtype, low_disk_space_usage, use_temp_file, cleanup_temp_file)
#    1336             weight_map[key] = filename
#    1338 if low_disk_space_usage and push_to_hub:
# -> 1339     upload_items(filename)
#    1340     os.remove(os.path.join(save_directory, filename)) # Remove to conserve disk space
#    1341 pass
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/unsloth_zoo/saving_utils.py:1104, in merge_and_overwrite_lora.<locals>.upload_items(filename)
#    1102     hf_api.upload_folder(folder_path = save_directory, **extras,)
#    1103 else:
# -> 1104     hf_api.upload_file(
#    1105         path_or_fileobj = os.path.join(save_directory, filename),
#    1106         path_in_repo = filename,
#    1107         **extras,
#    1108     )
#    1109 pass
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/huggingface_hub/hf_api.py:1687, in future_compatible.<locals>._inner(self, *args, **kwargs)
#    1684     return self.run_as_future(fn, self, *args, **kwargs)
#    1686 # Otherwise, call the function normally
# -> 1687 return fn(self, *args, **kwargs)
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/huggingface_hub/hf_api.py:4667, in HfApi.upload_file(self, path_or_fileobj, path_in_repo, repo_id, token, repo_type, revision, commit_message, commit_description, create_pr, parent_commit, run_as_future)
#    4659 commit_message = (
#    4660     commit_message if commit_message is not None else f"Upload {path_in_repo} with huggingface_hub"
#    4661 )
#    4662 operation = CommitOperationAdd(
#    4663     path_or_fileobj=path_or_fileobj,
#    4664     path_in_repo=path_in_repo,
#    4665 )
# -> 4667 commit_info = self.create_commit(
#    4668     repo_id=repo_id,
#    4669     repo_type=repo_type,
#    4670     operations=[operation],
#    4671     commit_message=commit_message,
#    4672     commit_description=commit_description,
#    4673     token=token,
#    4674     revision=revision,
#    4675     create_pr=create_pr,
#    4676     parent_commit=parent_commit,
#    4677 )
#    4679 if commit_info.pr_url is not None:
#    4680     revision = quote(_parse_revision_from_pr_url(commit_info.pr_url), safe="")
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/huggingface_hub/hf_api.py:1687, in future_compatible.<locals>._inner(self, *args, **kwargs)
#    1684     return self.run_as_future(fn, self, *args, **kwargs)
#    1686 # Otherwise, call the function normally
# -> 1687 return fn(self, *args, **kwargs)
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/huggingface_hub/hf_api.py:4229, in HfApi.create_commit(self, repo_id, operations, commit_message, commit_description, token, repo_type, revision, create_pr, num_threads, parent_commit, run_as_future)
#    4226 # If updating twice the same file or update then delete a file in a single commit
#    4227 _warn_on_overwriting_operations(operations)
# -> 4229 self.preupload_lfs_files(
#    4230     repo_id=repo_id,
#    4231     additions=additions,
#    4232     token=token,
#    4233     repo_type=repo_type,
#    4234     revision=unquoted_revision,  # first-class methods take unquoted revision
#    4235     create_pr=create_pr,
#    4236     num_threads=num_threads,
#    4237     free_memory=False,  # do not remove `CommitOperationAdd.path_or_fileobj` on LFS files for "normal" users
#    4238 )
#    4240 files_to_copy = _fetch_files_to_copy(
#    4241     copies=copies,
#    4242     repo_type=repo_type,
#    (...)   4246     endpoint=self.endpoint,
#    4247 )
#    4248 # Remove no-op operations (files that have not changed)
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/huggingface_hub/hf_api.py:4494, in HfApi.preupload_lfs_files(self, repo_id, additions, token, repo_type, revision, create_pr, num_threads, free_memory, gitignore_content)
#    4482 # Prepare upload parameters
#    4483 upload_kwargs = {
#    4484     "additions": new_lfs_additions_to_upload,
#    4485     "repo_type": repo_type,
#    (...)   4492     "revision": revision if not create_pr else None,
#    4493 }
# -> 4494 _upload_files(**upload_kwargs, num_threads=num_threads, create_pr=create_pr)  # type: ignore [arg-type]
#    4495 for addition in new_lfs_additions_to_upload:
#    4496     addition._is_uploaded = True
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/huggingface_hub/_commit_api.py:427, in _upload_files(additions, repo_type, repo_id, headers, endpoint, num_threads, revision, create_pr)
#     418     _upload_lfs_files(
#     419         actions=lfs_actions,
#     420         oid2addop=lfs_oid2addop,
#    (...)    423         num_threads=num_threads,
#     424     )
#     426 if len(xet_additions) > 0:
# --> 427     _upload_xet_files(
#     428         additions=xet_additions,
#     429         repo_type=repo_type,
#     430         repo_id=repo_id,
#     431         headers=headers,
#     432         endpoint=endpoint,
#     433         revision=revision,
#     434         create_pr=create_pr,
#     435     )
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/micromamba/envs/unsloth/lib/python3.11/site-packages/huggingface_hub/_commit_api.py:644, in _upload_xet_files(additions, repo_type, repo_id, headers, endpoint, revision, create_pr)
#     642 if len(all_paths_ops) > 0:
#     643     all_paths = [str(op.path_or_fileobj) for op in all_paths_ops]
# --> 644     upload_files(
#     645         all_paths,
#     646         xet_endpoint,
#     647         access_token_info,
#     648         token_refresher,
#     649         progress_callback,
#     650         repo_type,
#     651     )
#     653 if len(all_bytes_ops) > 0:
#     654     all_bytes = [op.path_or_fileobj for op in all_bytes_ops]
#
# KeyboardInterrupt:
